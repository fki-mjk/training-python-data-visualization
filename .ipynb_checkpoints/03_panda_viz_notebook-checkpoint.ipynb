# %% [markdown]
# # Pandas Viz Notebook

# %% [markdown]
# ## Part 1 : Pendahuluan

# %%
import pandas as pd

# %%
df = pd.read_csv('data/error_log_updated.csv')

# %% [markdown]
# ## Part 2: Bermain dengan Data

# %% [markdown]
# ### Akses Kolom pada Pandas

# %%
jenis_error = df['Jenis Error']
response_time = df['Response Time (ms)']

# %% [markdown]
# ### Melihat Data dengan Head dan Tail

# %%
df.head(5)
# Out:
#              Timestamp                Jenis Error  \
# 0  2024-01-01 00:00:00      InvalidInputException
# 1  2024-01-01 00:44:41      InvalidInputException
# 2  2024-01-01 01:29:22       NullPointerException
# 3  2024-01-01 02:14:03           Connection Error
# 4  2024-01-01 02:58:44  ResourceNotFoundException
#
#                         Pesan Error User ID Versi Aplikasi    Lokasi Platform  \
# 0                I/O error occurred  user97           v1.0     Medan      Web
# 1                Resource not found  user44           v1.0  Makassar      Web
# 2                Resource not found  user80           v2.0   Bandung  Android
# 3  Timeout while processing request  user61           v1.1   Jakarta      iOS
# 4                Resource not found  user43           v2.0   Jakarta      Web
#
#   Severity Level Browser/User Agent Sistem Operasi  Response Time (ms)  \
# 0        Warning        Firefox 108       macOS 13                 813
# ...

# %%
df.tail(50)
# Out:
#                Timestamp                Jenis Error  \
# 950  2024-01-30 11:30:27           Connection Error
# 951  2024-01-30 12:15:08      InvalidInputException
# 952  2024-01-30 12:59:49  ResourceNotFoundException
# 953  2024-01-30 13:44:30                IOException
# 954  2024-01-30 14:29:11      InvalidInputException
# 955  2024-01-30 15:13:52           Connection Error
# 956  2024-01-30 15:58:33  ResourceNotFoundException
# 957  2024-01-30 16:43:14  ResourceNotFoundException
# 958  2024-01-30 17:27:55       NullPointerException
# 959  2024-01-30 18:12:36           Connection Error
# 960  2024-01-30 18:57:17          Timeout Exception
# 961  2024-01-30 19:41:58  ResourceNotFoundException
# 962  2024-01-30 20:26:40           Connection Error
# 963  2024-01-30 21:11:21       NullPointerException
# 964  2024-01-30 21:56:02      InvalidInputException
# 965  2024-01-30 22:40:43           Connection Error
# 966  2024-01-30 23:25:24       NullPointerException
# ...

# %% [markdown]
# ### Melihat Informasi Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Timestamp             1000 non-null   object
#  1   Jenis Error           1000 non-null   object
#  2   Pesan Error           1000 non-null   object
#  3   User ID               1000 non-null   object
#  4   Versi Aplikasi        1000 non-null   object
#  5   Lokasi                1000 non-null   object
#  6   Platform              1000 non-null   object
#  7   Severity Level        1000 non-null   object
#  8   Browser/User Agent    1000 non-null   object
#  9   Sistem Operasi        1000 non-null   object
#  10  Response Time (ms)    1000 non-null   int64
#  11  Network Latency (ms)  1000 non-null   int64
#  12  CPU Usage (%)         1000 non-null   int64
# dtypes: int64(3), object(10)
# memory usage: 101.7+ KB

# %% [markdown]
# ### Menampilkan Statistik Deskriptif

# %%
df.describe()
# Out:
#        Response Time (ms)  Network Latency (ms)  CPU Usage (%)
# count         1000.000000           1000.000000    1000.000000
# mean          2685.824000            105.477000      53.125000
# std           1376.744145             55.758896      25.448989
# min            202.000000             10.000000      10.000000
# 25%           1489.250000             55.750000      32.000000
# 50%           2734.000000            106.000000      52.000000
# 75%           3894.250000            154.000000      75.000000
# max           4999.000000            199.000000      99.000000

# %% [markdown]
# ### Filter Data

# %%
high_cpu_usage = df[df['CPU Usage (%)'] > 80]

# %%
high_cpu_usage
# Out:
#                Timestamp                Jenis Error  \
# 2    2024-01-01 01:29:22       NullPointerException
# 21   2024-01-01 15:38:22      InvalidInputException
# 22   2024-01-01 16:23:03          Timeout Exception
# 28   2024-01-01 20:51:10  ResourceNotFoundException
# 30   2024-01-01 22:20:32      InvalidInputException
# ..                   ...                        ...
# 987  2024-01-31 15:03:47      InvalidInputException
# 988  2024-01-31 15:48:28           Connection Error
# 989  2024-01-31 16:33:09      InvalidInputException
# 996  2024-01-31 21:45:56           Connection Error
# 998  2024-01-31 23:15:18           Connection Error
#
#                           Pesan Error User ID Versi Aplikasi    Lokasi  \
# 2                  Resource not found  user80           v2.0   Bandung
# 21                 I/O error occurred  user61           v1.2     Medan
# 22                Null pointer access  user42           v2.0  Makassar
# ...

# %% [markdown]
# ### Sorting Data

# %%
sorted_df = df.sort_values('Response Time (ms)')

# %%
sorted_df.head(5)
# Out:
#                Timestamp            Jenis Error           Pesan Error User ID  \
# 717  2024-01-23 05:58:55       Connection Error  Invalid input format  user61
# 958  2024-01-30 17:27:55   NullPointerException   Null pointer access  user40
# 384  2024-01-12 21:58:55  InvalidInputException    I/O error occurred  user26
# 83   2024-01-03 13:48:49       Connection Error   Null pointer access  user34
# 328  2024-01-11 04:16:34       Connection Error  Invalid input format  user19
#
#     Versi Aplikasi    Lokasi Platform Severity Level Browser/User Agent  \
# 717           v1.1   Jakarta      Web       Critical        Firefox 108
# 958           v2.0  Surabaya      iOS       Critical         Chrome 110
# 384           v1.2     Medan      iOS          Error          Safari 16
# 83            v1.1   Bandung      iOS          Debug          Safari 16
# 328           v1.2   Jakarta      Web        Warning        Firefox 108
#
# ...

# %% [markdown]
# ### Group Data

# %%
error_per_platform = df.groupby('Platform').size()

# %%
error_per_platform
# Out:
# Platform
# Android    362
# Web        317
# iOS        321
# dtype: int64

# %% [markdown]
# ## Part 3 Visualisasi Data

# %% [markdown]
# ### Contoh Matplotlib & Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar chart frekuensi jenis error dengan Matplotlib
jenis_error_counts = df['Jenis Error'].value_counts()
plt.bar(jenis_error_counts.index, jenis_error_counts.values)
plt.xlabel("Jenis Error")
plt.ylabel("Frekuensi")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Scatter plot Response Time vs. CPU Usage dengan Seaborn
sns.scatterplot(x='Response Time (ms)', y='CPU Usage (%)', data=df)
plt.show()

# %% [markdown]
# ### Matplotlib: Grid dan Multiple Graph

# %%
plt.grid(True)  # Menambahkan grid
plt.show()

# %%
plt.grid(color='grey', linestyle='--', linewidth=0.5)

# %% [markdown]
# #### Multiple Graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Baca data
df = pd.read_csv('data/error_log_updated.csv')

# Membuat 2x1 grafik
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

# Bar chart frekuensi jenis error
jenis_error_counts = df['Jenis Error'].value_counts()
axes[0].bar(jenis_error_counts.index, jenis_error_counts.values)  # Menggunakan axes[0]
axes[0].set_xlabel("Jenis Error")
axes[0].set_ylabel("Frekuensi")
axes[0].grid(True)

# Scatter plot Response Time vs. CPU Usage
axes[1].scatter(df['Response Time (ms)'], df['CPU Usage (%)'])  # Menggunakan axes[1]
axes[1].set_xlabel("Response Time (ms)")
axes[1].set_ylabel("CPU Usage (%)")
axes[1].grid(True)

plt.tight_layout()  # Mengatur jarak antar grafik
plt.show()
